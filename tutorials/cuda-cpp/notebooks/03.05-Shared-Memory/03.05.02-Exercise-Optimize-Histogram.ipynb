# %% [markdown]
# # Exercise: Optimize Histogram
#
# You can allocate shared memory with `__shared__` memory space specifier.
#
# ![Shared](Images/shared.png "Shared")
#
# Use shared memory to optimize the performance of the histogram.  You will do this algorithm in two stages:
# 1. Compute a privatized histogram for each thread block.
# 2. Contribute the privatized histogram to the global histogram.

# %% [markdown]
# <details>
# <summary>Original code in case you need it.</summary>
#
# ```c++
# %%writefile Sources/shmem.cpp
# #include "ach.cuh"
#
# constexpr int num_bins = 10;
# constexpr float bin_width = 10;
#
# // 1. Remove `block_histograms` from kernel parameters
# __global__ void histogram_kernel(cuda::std::span<float> temperatures,
#                                  cuda::std::span<int> block_histograms,
#                                  cuda::std::span<int> histogram)
# {
#   // 2. Allocate `block_histogram` in shared memory and initialize it to 0
#   cuda::std::span<int> block_histogram =
#       block_histograms.subspan(blockIdx.x * histogram.size(), histogram.size());
#
#   int cell = blockIdx.x * blockDim.x + threadIdx.x;
#   int bin = static_cast<int>(temperatures[cell] / bin_width);
#
#   cuda::atomic_ref<int, cuda::thread_scope_block>
#     block_ref(block_histogram[bin]);
#   block_ref.fetch_add(1);
#   __syncthreads();
#
#   if (threadIdx.x < num_bins)
#   {
#     cuda::atomic_ref<int, cuda::thread_scope_device> ref(histogram[threadIdx.x]);
#     ref.fetch_add(block_histogram[threadIdx.x]);
#   }
# }
#
# void histogram(cuda::std::span<float> temperatures,
#                cuda::std::span<int> block_histograms,
#                cuda::std::span<int> histogram, cudaStream_t stream) {
#   int block_size = 256;
#   int grid_size = cuda::ceil_div(temperatures.size(), block_size);
#   histogram_kernel<<<grid_size, block_size, 0, stream>>>(
#       temperatures, block_histograms, histogram);
# }
# ```
#
# </details>

# %%
import os

if os.getenv("COLAB_RELEASE_TAG"): # If running in Google Colab:
  # !mkdir -p Sources
  # !wget https://raw.githubusercontent.com/NVIDIA/accelerated-computing-hub/refs/heads/main/tutorials/cuda-cpp/notebooks/03.05-Shared-Memory/Sources/ach.cuh -nv -O Sources/ach.cuh
  # !wget https://raw.githubusercontent.com/NVIDIA/accelerated-computing-hub/refs/heads/main/tutorials/cuda-cpp/notebooks/03.05-Shared-Memory/Sources/__init__.py -nv -O Sources/__init__.py
  # !wget https://raw.githubusercontent.com/NVIDIA/accelerated-computing-hub/refs/heads/main/tutorials/cuda-cpp/notebooks/03.05-Shared-Memory/Sources/ach.py -nv -O Sources/ach.py
# Out:
# 2026-05-15 07:53:20 URL:https://raw.githubusercontent.com/NVIDIA/accelerated-computing-hub/refs/heads/main/tutorials/cuda-cpp/notebooks/03.05-Shared-Memory/Sources/ach.cuh [6176/6176] -> "Sources/ach.cuh" [1]
# 2026-05-15 07:53:21 URL:https://raw.githubusercontent.com/NVIDIA/accelerated-computing-hub/refs/heads/main/tutorials/cuda-cpp/notebooks/03.05-Shared-Memory/Sources/__init__.py [19/19] -> "Sources/__init__.py" [1]
# 2026-05-15 07:53:21 URL:https://raw.githubusercontent.com/NVIDIA/accelerated-computing-hub/refs/heads/main/tutorials/cuda-cpp/notebooks/03.05-Shared-Memory/Sources/ach.py [3742/3742] -> "Sources/ach.py" [1]

# %%
# %%writefile Sources/shmem.cpp
# #include "ach.cuh"
#
# constexpr int num_bins = 10;
# constexpr float bin_width = 10;
#
# // TODO: Remove `block_histograms` from kernel parameters
# __global__ void histogram_kernel(cuda::std::span<float> temperatures,
#                                  cuda::std::span<int> histogram)
# {
#   // TODO: Allocate `block_histogram` in shared memory and initialize it to 0
#   // cuda::std::span<int> block_histogram =
#   //     block_histograms.subspan(blockIdx.x * histogram.size(), histogram.size());
#
#   int cell = blockIdx.x * blockDim.x + threadIdx.x;
#   int bin = static_cast<int>(temperatures[cell] / bin_width);
#
#   __shared__ int block_histogram[num_bins];
#   // if (threadIdx.x < num_bins)
#   // {
#   //   block_histogram[threadIdx.x] = 0;
#   // }
#   __syncthreads();
#
#
#   cuda::atomic_ref<int, cuda::thread_scope_block>
#     block_ref(block_histogram[bin]);
#   block_ref.fetch_add(1);
#   __syncthreads();
#
#   if (threadIdx.x < num_bins)
#   {
#     cuda::atomic_ref<int, cuda::thread_scope_device> ref(histogram[threadIdx.x]);
#     ref.fetch_add(block_histogram[threadIdx.x]);
#   }
# }
#
# void histogram(cuda::std::span<float> temperatures,
#                cuda::std::span<int> block_histograms,
#                cuda::std::span<int> histogram, cudaStream_t stream) {
#   int block_size = 256;
#   int grid_size = cuda::ceil_div(temperatures.size(), block_size);
#   histogram_kernel<<<grid_size, block_size, 0, stream>>>(
#       temperatures, histogram);
# }
# Out:
# Overwriting Sources/shmem.cpp

# %%
# !pip install jupyter_dark_detect
# Out:
# Requirement already satisfied: jupyter_dark_detect in /usr/local/lib/python3.12/dist-packages (0.1.0)
# Requirement already satisfied: ipython>=7.0.0 in /usr/local/lib/python3.12/dist-packages (from jupyter_dark_detect) (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (0.20.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.0.0->jupyter_dark_detect) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.0.0->jupyter_dark_detect) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.0.0->jupyter_dark_detect) (0.6.0)

# %%
import Sources.ach
Sources.ach.run("Sources/shmem.cpp")
# Out:
# <video width="800" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# If you’re unsure how to proceed, consider expanding this section for guidance. Use the hint only after giving the problem a genuine attempt.
#
# <details>
#   <summary>Hints</summary>
#
#   - You can allocate shared memory using the `__shared__` keyword
# </details>

# %% [markdown]
# Open this section only after you’ve made a serious attempt at solving the problem. Once you’ve completed your solution, compare it with the reference provided here to evaluate your approach and identify any potential improvements.
#
# <details>
#   <summary>Solution</summary>
#
#   Key points:
#
#   - Allocate a shared memory array
#
#   Solution:
#   ```c++
#   __shared__ int block_histogram[num_bins];
#
#   if (threadIdx.x < num_bins)
#   {
#     block_histogram[threadIdx.x] = 0;
#   }
#   __syncthreads();
#
#   int cell = blockIdx.x * blockDim.x + threadIdx.x;
#   int bin = static_cast<int>(temperatures[cell] / bin_width);
#
#   cuda::atomic_ref<int, cuda::thread_scope_block>
#     block_ref(block_histogram[bin]);
#   block_ref.fetch_add(1, cuda::memory_order_relaxed);
#   __syncthreads();
#
#   if (threadIdx.x < num_bins)
#   {
#     cuda::atomic_ref<int, cuda::thread_scope_device> ref(histogram[threadIdx.x]);
#     ref.fetch_add(block_histogram[threadIdx.x], cuda::memory_order_relaxed);
#   }
#   ```
#
#   You can find full solution [here](Solutions/shmem.cpp).
# </details>

# %% [markdown]
# ---
# Congratulations!  Move on to the [next section](../03.06-Cooperative-Algorithms/03.06.01-Cooperative.ipynb).
